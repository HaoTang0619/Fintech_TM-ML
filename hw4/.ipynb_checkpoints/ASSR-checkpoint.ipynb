# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt

week_data = pd.read_csv('df_week_data.csv')
month_data = pd.read_csv('df_month_data.csv')

# %%
week_data
# Out:
#      Unnamed: 0       XLE      AMLP       VDE       AMJ      EMLP       XOP  \
# 0             0 -0.076153 -0.097156 -0.077032 -0.083959 -0.031124 -0.094157
# 1             1 -0.031168 -0.119363 -0.028001 -0.108684 -0.051515 -0.097631
# 2             2  0.024867  0.010499  0.020149  0.004658  0.025399  0.049320
# 3             3  0.042517  0.046308  0.042026  0.056180  0.047271  0.071068
# 4             4 -0.040708 -0.043081 -0.037347 -0.045989  0.012229 -0.084083
# 5             5 -0.011940 -0.128130 -0.012072 -0.112564 -0.055751 -0.072117
# 6             6  0.026917  0.104222  0.025217  0.093766  0.045913 -0.028017
# 7             7  0.007496  0.041719  0.009574  0.035768  0.016520  0.034942
# 8             8  0.061169  0.070505  0.071622  0.067624  0.037116  0.146610
# 9             9  0.022403 -0.010689  0.018460 -0.009822  0.012048  0.027279
# 10           10  0.024772  0.048588  0.023580  0.046387  0.022029  0.039469
# ...

# %%
my_data = genfromtxt('df_week_data.csv', delimiter=',').T
my_data[1]
# Out:
# array([        nan, -0.07615309, -0.03116778,  0.02486679,  0.04251701,
#        -0.04070796, -0.0119403 ,  0.02691712,  0.00749568,  0.06116925,
#         0.02240254,  0.02477206, -0.02666902, -0.01288014,  0.02101576,
#         0.01839436,  0.05229717,  0.00679612, -0.03413655, -0.00436975,
#         0.01766551,  0.01448096, -0.00886408,  0.01232166, -0.00064893,
#        -0.00162496,  0.02657387, -0.01314103,  0.02194357, -0.0133418 ,
#        -0.01384863,  0.00208902,  0.01705892,  0.0243489 , -0.01485768,
#        -0.00439837,  0.00887436, -0.02702271,  0.00271089,  0.04215671,
#         0.        , -0.01158838,  0.00553165, -0.01181592, -0.02371479,
#         0.02437888,  0.02350265,  0.02180362,  0.02825022,  0.02309209,
#         0.00406675, -0.00210793, -0.01367521,  0.00749328, -0.02019328,
#         0.00215889, -0.00419136, -0.01140184, -0.00161054, -0.01818724,
#        -0.01375246,  0.01385991, -0.02835249,  0.00305577, -0.01804324,
# ...
